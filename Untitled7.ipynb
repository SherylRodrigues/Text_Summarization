# %%
import codecs
import re
each_one=[]
list_of_sentences=[]
with codecs.open('sov.txt', encoding='utf-8') as f:
    text=f.read()
#def split_sentences(text):
    sentences = re.split(r' *[\.\?!][\'"\)\]]* *', text)
    for stuff in sentences:
        list_of_sentences.append(stuff)
        print stuff  
        
print(list_of_sentences)
# Out:
# सनरायझर्साक बॅटींग दिलें
# सनरायझर्सांनी लाव घेतलो
# सनरायझर्स सके जोडलें
# इंडियन्सान  खातें उगडलें
# शर्मान विकेट घेतली
# भारतीय आव्हान सोंपलें
#
#
# [u'\u0938\u0928\u0930\u093e\u092f\u091d\u0930\u094d\u0938\u093e\u0915 \u092c\u0945\u091f\u0940\u0902\u0917 \u0926\u093f\u0932\u0947\u0902', u'\u0938\u0928\u0930\u093e\u092f\u091d\u0930\u094d\u0938\u093e\u0902\u0928\u0940 \u0932\u093e\u0935 \u0918\u0947\u0924\u0932\u094b', u'\u0938\u0928\u0930\u093e\u092f\u091d\u0930\u094d\u0938 \u0938\u0915\u0947 \u091c\u094b\u0921\u0932\u0947\u0902', u'\u0907\u0902\u0921\u093f\u092f\u0928\u094d\u0938\u093e\u0928  \u0916\u093e\u0924\u0947\u0902 \u0909\u0917\u0921\u0932\u0947\u0902', u'\u0936\u0930\u094d\u092e\u093e\u0928 \u0935\u093f\u0915\u0947\u091f \u0918\u0947\u0924\u0932\u0940', u'\u092d\u093e\u0930\u0924\u0940\u092f \u0906\u0935\u094d\u0939\u093e\u0928 \u0938\u094b\u0902\u092a\u0932\u0947\u0902', u'\n']

# %%
#!/usr/bin/env python 
# -- coding: utf-8 -- 

f = open('sov_dict.txt', 'r')
subject_list=[]
object_list=[]
verb_list=[]
pos_triple=[]
newDict = {}
for sent in list_of_sentences:
    for line in f:
        k,v = line.strip().split('/')
        newDict[k.strip()] = v.strip()
        if v=='N-NNP':
            subject_list.append(k)
            print('SUBJECT:',subject_list)
            #for i in subject_list[0]:
                #print(i)
        if v=='N-NN':
            object_list.append(k)
            print('OBJECT',object_list)                 
        if v=='V-VM-VF':
            verb_list.append(k)
            print('VERB',verb_list)
        
        pos_triple=subject_list+object_list+verb_list
            
            

#print u'Subject list is:'
#print subject_list
#print u'Object list is:'
#print object_list
#print u'Verb list is:'
#print verb_list

#print u'POS triple:'
#pos_triple=subject_list+object_list+verb_list
#print pos_triple

# %matplotlib notebook
import networkx as nx
import matplotlib.pyplot as pl
from matplotlib.font_manager import FontProperties
prop= FontProperties()

labels={}
graph = nx.Graph()

#words= ["सनरायझर्साक","विकेटीन","जैत"]

for subject in subject_list:
    s=subject.decode('utf-8')
    graph.add_node(s)
    labels[s]=s

    
for obj in object_list:
    b=obj.decode('utf-8')
    graph.add_node(b)
    labels[b]=b
    
for verb in verb_list:
    v=verb.decode('utf-8')
    graph.add_node(v)
    labels[v]=v
#for word in pos_triple:
   # w = word.decode('utf-8')
   # graph.add_node(w)
   # labels[w]=w
    
graph.add_edge(subject_list[0].decode('utf-8'),object_list[0].decode('utf-8'))
graph.add_edge(object_list[0].decode('utf-8'),verb_list[0].decode('utf-8'))

graph.add_edge(subject_list[1].decode('utf-8'),object_list[1].decode('utf-8'))
graph.add_edge(object_list[1].decode('utf-8'),verb_list[1].decode('utf-8'))


graph.add_edge(subject_list[2].decode('utf-8'),object_list[2].decode('utf-8'))
graph.add_edge(object_list[2].decode('utf-8'),verb_list[2].decode('utf-8'))

graph.add_edge(subject_list[3].decode('utf-8'),object_list[3].decode('utf-8'))
graph.add_edge(object_list[3].decode('utf-8'),verb_list[3].decode('utf-8'))

graph.add_edge(subject_list[4].decode('utf-8'),object_list[4].decode('utf-8'))
graph.add_edge(object_list[4].decode('utf-8'),verb_list[4].decode('utf-8'))
graph.add_edge(subject_list[5].decode('utf-8'),object_list[5].decode('utf-8'))
graph.add_edge(object_list[5].decode('utf-8'),verb_list[5].decode('utf-8'))

#graph.add_edge("सनरायझर्साक".decode('utf-8'),"колектив".decode('utf-8'))
pos=nx.spring_layout(graph)
# pos=nx.drawing.pydot_layout(graph) # doesn't work with unicode
# pos=nx.drawing.pygraphviz_layout(graph) # this also works, pygraphviz
nx.draw(graph, with_labels = True, font_family = "Nirmala UI", node_size = 40, font_size = 10, node_color = "lightblue")
#nx.draw(graph,labels=words, with_labels = True)
pl.show()
# Out:
# ('SUBJECT:', ['\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8\xe0\xa4\xbe\xe0\xa4\x95'])
# ('OBJECT', ['\xe0\xa4\xac\xe0\xa5\x85\xe0\xa4\x9f\xe0\xa5\x80\xe0\xa4\x82\xe0\xa4\x97'])
# ('VERB', ['\xe0\xa4\xa6\xe0\xa4\xbf\xe0\xa4\xb2\xe0\xa5\x87\xe0\xa4\x82'])
# ('SUBJECT:', ['\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8\xe0\xa4\xbe\xe0\xa4\x95', '\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8\xe0\xa4\xbe\xe0\xa4\x82\xe0\xa4\xa8\xe0\xa5\x80'])
# ('OBJECT', ['\xe0\xa4\xac\xe0\xa5\x85\xe0\xa4\x9f\xe0\xa5\x80\xe0\xa4\x82\xe0\xa4\x97', '\xe0\xa4\xb2\xe0\xa4\xbe\xe0\xa4\xb5'])
# ('VERB', ['\xe0\xa4\xa6\xe0\xa4\xbf\xe0\xa4\xb2\xe0\xa5\x87\xe0\xa4\x82', '\xe0\xa4\x98\xe0\xa5\x87\xe0\xa4\xa4\xe0\xa4\xb2\xe0\xa5\x8b'])
# ('SUBJECT:', ['\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8\xe0\xa4\xbe\xe0\xa4\x95', '\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8\xe0\xa4\xbe\xe0\xa4\x82\xe0\xa4\xa8\xe0\xa5\x80', '\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8'])
# ('OBJECT', ['\xe0\xa4\xac\xe0\xa5\x85\xe0\xa4\x9f\xe0\xa5\x80\xe0\xa4\x82\xe0\xa4\x97', '\xe0\xa4\xb2\xe0\xa4\xbe\xe0\xa4\xb5', '\xe0\xa4\xb8\xe0\xa4\x95\xe0\xa5\x87'])
# ('VERB', ['\xe0\xa4\xa6\xe0\xa4\xbf\xe0\xa4\xb2\xe0\xa5\x87\xe0\xa4\x82', '\xe0\xa4\x98\xe0\xa5\x87\xe0\xa4\xa4\xe0\xa4\xb2\xe0\xa5\x8b', '\xe0\xa4\x9c\xe0\xa5\x8b\xe0\xa4\xa1\xe0\xa4\xb2\xe0\xa5\x87\xe0\xa4\x82'])
# ('SUBJECT:', ['\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8\xe0\xa4\xbe\xe0\xa4\x95', '\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8\xe0\xa4\xbe\xe0\xa4\x82\xe0\xa4\xa8\xe0\xa5\x80', '\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8', '\xe0\xa4\x87\xe0\xa4\x82\xe0\xa4\xa1\xe0\xa4\xbf\xe0\xa4\xaf\xe0\xa4\xa8\xe0\xa5\x8d\xe0\xa4\xb8\xe0\xa4\xbe\xe0\xa4\xa8'])
# ('OBJECT', ['\xe0\xa4\xac\xe0\xa5\x85\xe0\xa4\x9f\xe0\xa5\x80\xe0\xa4\x82\xe0\xa4\x97', '\xe0\xa4\xb2\xe0\xa4\xbe\xe0\xa4\xb5', '\xe0\xa4\xb8\xe0\xa4\x95\xe0\xa5\x87', '\xe0\xa4\x96\xe0\xa4\xbe\xe0\xa4\xa4\xe0\xa5\x87\xe0\xa4\x82'])
# ('VERB', ['\xe0\xa4\xa6\xe0\xa4\xbf\xe0\xa4\xb2\xe0\xa5\x87\xe0\xa4\x82', '\xe0\xa4\x98\xe0\xa5\x87\xe0\xa4\xa4\xe0\xa4\xb2\xe0\xa5\x8b', '\xe0\xa4\x9c\xe0\xa5\x8b\xe0\xa4\xa1\xe0\xa4\xb2\xe0\xa5\x87\xe0\xa4\x82', '\xe0\xa4\x89\xe0\xa4\x97\xe0\xa4\xa1\xe0\xa4\xb2\xe0\xa5\x87\xe0\xa4\x82'])
# ('SUBJECT:', ['\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8\xe0\xa4\xbe\xe0\xa4\x95', '\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8\xe0\xa4\xbe\xe0\xa4\x82\xe0\xa4\xa8\xe0\xa5\x80', '\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8', '\xe0\xa4\x87\xe0\xa4\x82\xe0\xa4\xa1\xe0\xa4\xbf\xe0\xa4\xaf\xe0\xa4\xa8\xe0\xa5\x8d\xe0\xa4\xb8\xe0\xa4\xbe\xe0\xa4\xa8', '\xe0\xa4\xb6\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xae\xe0\xa4\xbe\xe0\xa4\xa8'])
# ('OBJECT', ['\xe0\xa4\xac\xe0\xa5\x85\xe0\xa4\x9f\xe0\xa5\x80\xe0\xa4\x82\xe0\xa4\x97', '\xe0\xa4\xb2\xe0\xa4\xbe\xe0\xa4\xb5', '\xe0\xa4\xb8\xe0\xa4\x95\xe0\xa5\x87', '\xe0\xa4\x96\xe0\xa4\xbe\xe0\xa4\xa4\xe0\xa5\x87\xe0\xa4\x82', '\xe0\xa4\xb5\xe0\xa4\xbf\xe0\xa4\x95\xe0\xa5\x87\xe0\xa4\x9f'])
# ('VERB', ['\xe0\xa4\xa6\xe0\xa4\xbf\xe0\xa4\xb2\xe0\xa5\x87\xe0\xa4\x82', '\xe0\xa4\x98\xe0\xa5\x87\xe0\xa4\xa4\xe0\xa4\xb2\xe0\xa5\x8b', '\xe0\xa4\x9c\xe0\xa5\x8b\xe0\xa4\xa1\xe0\xa4\xb2\xe0\xa5\x87\xe0\xa4\x82', '\xe0\xa4\x89\xe0\xa4\x97\xe0\xa4\xa1\xe0\xa4\xb2\xe0\xa5\x87\xe0\xa4\x82', '\xe0\xa4\x98\xe0\xa5\x87\xe0\xa4\xa4\xe0\xa4\xb2\xe0\xa5\x80'])
# ('SUBJECT:', ['\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8\xe0\xa4\xbe\xe0\xa4\x95', '\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8\xe0\xa4\xbe\xe0\xa4\x82\xe0\xa4\xa8\xe0\xa5\x80', '\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8', '\xe0\xa4\x87\xe0\xa4\x82\xe0\xa4\xa1\xe0\xa4\xbf\xe0\xa4\xaf\xe0\xa4\xa8\xe0\xa5\x8d\xe0\xa4\xb8\xe0\xa4\xbe\xe0\xa4\xa8', '\xe0\xa4\xb6\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xae\xe0\xa4\xbe\xe0\xa4\xa8', '\xe0\xa4\xad\xe0\xa4\xbe\xe0\xa4\xb0\xe0\xa4\xa4\xe0\xa5\x80\xe0\xa4\xaf'])
# ('OBJECT', ['\xe0\xa4\xac\xe0\xa5\x85\xe0\xa4\x9f\xe0\xa5\x80\xe0\xa4\x82\xe0\xa4\x97', '\xe0\xa4\xb2\xe0\xa4\xbe\xe0\xa4\xb5', '\xe0\xa4\xb8\xe0\xa4\x95\xe0\xa5\x87', '\xe0\xa4\x96\xe0\xa4\xbe\xe0\xa4\xa4\xe0\xa5\x87\xe0\xa4\x82', '\xe0\xa4\xb5\xe0\xa4\xbf\xe0\xa4\x95\xe0\xa5\x87\xe0\xa4\x9f', '\xe0\xa4\x86\xe0\xa4\xb5\xe0\xa5\x8d\xe0\xa4\xb9\xe0\xa4\xbe\xe0\xa4\xa8'])
# ('VERB', ['\xe0\xa4\xa6\xe0\xa4\xbf\xe0\xa4\xb2\xe0\xa5\x87\xe0\xa4\x82', '\xe0\xa4\x98\xe0\xa5\x87\xe0\xa4\xa4\xe0\xa4\xb2\xe0\xa5\x8b', '\xe0\xa4\x9c\xe0\xa5\x8b\xe0\xa4\xa1\xe0\xa4\xb2\xe0\xa5\x87\xe0\xa4\x82', '\xe0\xa4\x89\xe0\xa4\x97\xe0\xa4\xa1\xe0\xa4\xb2\xe0\xa5\x87\xe0\xa4\x82', '\xe0\xa4\x98\xe0\xa5\x87\xe0\xa4\xa4\xe0\xa4\xb2\xe0\xa5\x80', '\xe0\xa4\xb8\xe0\xa5\x8b\xe0\xa4\x82\xe0\xa4\xaa\xe0\xa4\xb2\xe0\xa5\x87\xe0\xa4\x82'])
# <img src="data:image/png;base64,..." width="640">

# %%
#!/usr/bin/env python 
# -- coding: utf-8 -- 
# %matplotlib notebook
import matplotlib.font_manager as fm 
import matplotlib.pyplot as plt 
import networkx as nx
prop = fm.FontProperties(fname='C:\\Users\\Solange\\Anaconda2\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\NotoSerifDevanagari-Regular.ttf') 
x=0.2
y=0.2
labels={}
graph = nx.Graph()

words= ["सनरायझर्स"," जैत ","जोडलें"]
#words= ["x","y","z"]

for word in words:
    w = word.decode('utf-8')
    graph.add_node(w)
    labels[w]=w
graph.add_edge(words[0].decode('utf-8'),words[1].decode('utf-8'))
graph.add_edge(words[1].decode('utf-8'),words[2].decode('utf-8'))
#graph.add_edge("सनरायझर्साक".decode('utf-8'),"колектив".decode('utf-8'))
#nx.draw_networkx(graph,pos=positions)

   

pos=nx.spring_layout(graph)
# pos=nx.drawing.pydot_layout(graph) # doesn't work with unicode
# pos=nx.drawing.pygraphviz_layout(graph) # this also works, pygraphviz
#nx.draw_networkx(graph, pos=pos, labels=labels,fontproperties=prop)
#nx.draw(graph,labels=words, with_labels = True)
nx.draw(graph, with_labels = True, font_family = "Nirmala UI", node_size = 1200, font_size = 10, node_color = "lightblue")
#labels=nx.draw_networkx_labels(graph,pos=nx.spring_layout(graph))

#plt.text(x, y, word, fontproperties=prop) 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from fontTools.ttLib import TTFont
import matplotlib.font_manager as mfm

def char_in_font(unicode_char, font):
    for cmap in font['cmap'].tables:
        if cmap.isUnicode():
            if ord(unicode_char) in cmap.cmap:
                return True
    return False

#uni_char =  u"✹"
uni_char = u"क"

font_info = [(f.fname, f.name) for f in mfm.fontManager.ttflist]

for i, font in enumerate(font_info):
    if char_in_font(uni_char, TTFont(font[0])):
        print(font[0], font[1])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-a89ab9694c05> in <module>()
# ----> 1 from fontTools.ttLib import TTFont
#       2 import matplotlib.font_manager as mfm
#       3
#       4 def char_in_font(unicode_char, font):
#       5     for cmap in font['cmap'].tables:
#
# ImportError: No module named fontTools.ttLib

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as mfm

font_path = 'C:\\Users\\Solange\\Anaconda2\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansMono.ttf'
prop = mfm.FontProperties(fname=font_path)
plt.text(0.5, 0.5, s=uni_char, fontproperties=prop, fontsize=20)

plt.show()

# %%
#-*- coding: utf-8 -*-
graph = { "सनरायझर्स" : ["जैत "],
          "b" : ["जैत ", "e"],
          "जैत " : ["सनरायझर्", "b", "d", "e"],
          "d" : ["जैत "],
          "e" : ["जैत ", "b"],
          "f" : []
        }

# %%
#-*- coding: utf-8 -*-
ls=[]
def generate_edges(graph):
    edges = []
    for node in graph:
        for neighbour in graph[node]:
            edges.append((node, neighbour))
  
    return edges

#for i in ls[0]:
    #print i

print(generate_edges(graph))
# Out:
# [('b', '\xe0\xa4\x9c\xe0\xa5\x88\xe0\xa4\xa4 '), ('b', 'e'), ('e', '\xe0\xa4\x9c\xe0\xa5\x88\xe0\xa4\xa4 '), ('e', 'b'), ('d', '\xe0\xa4\x9c\xe0\xa5\x88\xe0\xa4\xa4 '), ('\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d\xe0\xa4\xb8', '\xe0\xa4\x9c\xe0\xa5\x88\xe0\xa4\xa4 '), ('\xe0\xa4\x9c\xe0\xa5\x88\xe0\xa4\xa4 ', '\xe0\xa4\xb8\xe0\xa4\xa8\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xaf\xe0\xa4\x9d\xe0\xa4\xb0\xe0\xa5\x8d'), ('\xe0\xa4\x9c\xe0\xa5\x88\xe0\xa4\xa4 ', 'b'), ('\xe0\xa4\x9c\xe0\xa5\x88\xe0\xa4\xa4 ', 'd'), ('\xe0\xa4\x9c\xe0\xa5\x88\xe0\xa4\xa4 ', 'e')]

# %%
#!/usr/bin/env python 
# -- coding: utf-8 -- 
# %matplotlib notebook
import matplotlib.font_manager as fm 
import matplotlib.pyplot as plt 
prop = fm.FontProperties(fname='C:\\Users\\Solange\\Anaconda2\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\NotoSerifDevanagari-Regular.ttf') 
s = u'सनरायझर्स' 
x = 0.2 
y = 0.2 
plt.text(x, y, s, fontproperties=prop) 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
import networkx as nx

font_names = ['Sawasdee', 'Gentium Book Basic', 'FreeMono', ]
family_names = ['sans-serif', 'serif', 'fantasy', 'monospace']


# Make a graph
G  = nx.generators.florentine_families_graph()

# need some positions for the nodes, so lay it out
pos = nx.spring_layout(G)

# create some maps for some subgraphs (not elegant way)
subgraph_members  = [G.nodes()[i:i+3] for i in xrange(0, len(G.nodes()), 3)]

plt.figure(1)
nx.draw_networkx_nodes(G, pos)


for i, nodes in enumerate(subgraph_members):
    f = font_names[(i % 3)]
    #f = family_names[(i % 4)]
    # extract the subgraph
    g = G.subgraph(subgraph_members[i])
    # draw on the labels with different fonts
    nx.draw_networkx_labels(g, pos, font_family=f, font_size=40)

# show the edges too
nx.draw_networkx_edges(G, pos)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-47c8d0c89060> in <module>()
#      13
#      14 # create some maps for some subgraphs (not elegant way)
# ---> 15 subgraph_members  = [G.nodes()[i:i+3] for i in xrange(0, len(G.nodes()), 3)]
#      16
#      17 plt.figure(1)
#
# C:\Users\Solange\Anaconda2\lib\site-packages\networkx\classes\reportviews.pyc in __getitem__(self, n)
#     176
#     177     def __getitem__(self, n):
# --> 178         return self._nodes[n]
#     179
#     180     # Set methods
#
# TypeError: unhashable type

# %%
#!/usr/bin/env python 
# -- coding: utf-8 -- 
# %matplotlib notebook
import matplotlib.font_manager as fm 
print([f.name for f in fm.fontManager.ttflist])
import matplotlib.pyplot as plt 
avail_font_names = [f.name for fm in matplotlib.font_manager.fontManager.ttflist]
# Out:
# [u'STIXGeneral', u'STIXSizeFourSym', u'DejaVu Serif', u'STIXSizeFourSym', u'STIXNonUnicode', u'STIXSizeTwoSym', u'DejaVu Sans Display', u'STIXSizeOneSym', u'STIXSizeTwoSym', u'DejaVu Serif Display', u'STIXSizeThreeSym', u'cmr10', u'STIXNonUnicode', u'STIXSizeThreeSym', u'STIXGeneral', u'DejaVu Sans', u'cmb10', u'DejaVu Sans Mono', u'cmss10', u'STIXNonUnicode', u'cmsy10', u'DejaVu Sans', u'DejaVu Sans', u'DejaVu Sans Mono', u'DejaVu Sans', u'DejaVu Serif', u'DejaVu Serif', u'STIXNonUnicode', u'STIXSizeFiveSym', u'STIXGeneral', u'cmtt10', u'DejaVu Serif', u'STIXGeneral', u'DejaVu Sans Mono', u'cmmi10', u'STIXSizeOneSym', u'cmex10', u'DejaVu Sans Mono', u'High Tower Text', u'Footlight MT Light', u'Comic Sans MS', u'Cambria', u'Agency FB', u'Rockwell Nova', u'JasmineUPC', u'Book Antiqua', u'Trebuchet MS', u'Khmer UI', u'Bell MT', u'Bodoni MT', u'Rockwell Extra Bold', u'Georgia Pro', u'Century Gothic', u'FreesiaUPC', u'Urdu Typesetting', u'Arial Nova', u'KaiTi', u'Microsoft Sans Serif', u'Showcard Gothic', u'Segoe UI Historic', u'Candara', u'Microsoft Tai Le', u'Franklin Gothic Demi', u'Trebuchet MS', u'Monotype Corsiva', u'Segoe UI', u'Bodoni MT', u'Urdu Typesetting', u'Bodoni MT', u'Gill Sans MT', u'Segoe UI', u'Imprint MT Shadow', u'MoolBoran', u'Arial', u'Segoe UI', u'Franklin Gothic Demi', u'Magneto', u'Tw Cen MT Condensed', u'Simplified Arabic', u'Arabic Typesetting', u'Aparajita', u'Khmer UI', u'Segoe UI', u'Verdana Pro', u'Shruti', u'Verdana Pro', u'Wingdings 2', u'Times New Roman', u'Perpetua', u'Georgia', u'Lucida Handwriting', u'Gill Sans Nova', u'Constantia', u'Pristina', u'Gill Sans MT', u'DFKai-SB', u'Nirmala UI', u'Verdana Pro', u'Neue Haas Grotesk Text Pro', u'Tahoma', u'Urdu Typesetting', u'Kokila', u'Californian FB', u'Gill Sans Nova', u'Kunstler Script', u'Georgia Pro', u'Sanskrit Text', u'Consolas', u'Curlz MT', u'Arial', u'Perpetua', u'Old English Text MT', u'Parchment', u'Tw Cen MT Condensed Extra Bold', u'Arial', u'Berlin Sans FB', u'Verdana Pro', u'Corbel', u'Bodoni MT', u'Colonna MT', u'Bodoni MT', u'Verdana', u'Rockwell Nova', u'Georgia', u'Bodoni MT', u'Maiandra GD', u'Franklin Gothic Book', u'Constantia', u'Gill Sans MT Condensed', u'Gill Sans Nova', u'Onyx', u'Verdana Pro', u'Book Antiqua', u'Gill Sans Nova', u'Book Antiqua', u'Verdana Pro', u'Garamond', u'Simplified Arabic', u'Castellar', u'Arial Nova', u'Chiller', u'Segoe MDL2 Assets', u'Informal Roman', u'Eras Bold ITC', u'Neue Haas Grotesk Text Pro', u'Rockwell Condensed', u'TeamViewer13', u'Agency FB', u'Palace Script MT', u'Nirmala UI', u'Vijaya', u'Cooper Black', u'Arial', u'Georgia Pro', u'Neue Haas Grotesk Text Pro', u'Segoe UI Emoji', u'Lucida Sans Typewriter', u'Verdana Pro', u'Arial Rounded MT Bold', u'Arial Nova', u'Gill Sans MT', u'Bahnschrift', u'Georgia Pro', u'EucrosiaUPC', u'Rockwell Nova', u'Arial Nova', u'Kartika', u'Miriam Fixed', u'Utsaah', u'Arial', u'Modern No. 20', u'Century Schoolbook', u'Kristen ITC', u'Segoe UI', u'Microsoft New Tai Lue', u'OCR A Extended', u'Calisto MT', u'Segoe UI', u'Gill Sans Nova', u'Shonar Bangla', u'Verdana Pro', u'Lucida Sans', u'Bodoni MT', u'Gabriola', u'Eras Medium ITC', u'Verdana', u'Yu Mincho', u'Franklin Gothic Demi', u'Aparajita', u'Palatino Linotype', u'Utsaah', u'Bodoni MT', u'Symbol', u'Monotype Corsiva', u'Gill Sans Nova', u'Lucida Sans', u'Sylfaen', u'Rockwell Nova', u'Rockwell Condensed', u'Verdana Pro', u'Agency FB', u'Century Schoolbook', u'Arial', u'Javanese Text', u'Aharoni', u'Georgia Pro', u'DengXian', u'Palatino Linotype', u'Utsaah', u'Georgia Pro', u'Lucida Fax', u'Nirmala UI', u'Century Schoolbook', u'LilyUPC', u'EucrosiaUPC', u'Myanmar Text', u'Georgia Pro', u'Aparajita', u'Nirmala UI', u'Viner Hand ITC', u'LilyUPC', u'Georgia Pro', u'Britannic Bold', u'KodchiangUPC', u'Gadugi', u'Segoe UI', u'KodchiangUPC', u'Verdana Pro', u'Courier New', u'Gill Sans MT', u'Rockwell Nova', u'MS Reference Specialty', u'Iskoola Pota', u'Georgia Pro', u'Bookman Old Style', u'Verdana Pro', u'Verdan ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-43bdfa9d72eb> in <module>()
#       5 print([f.name for f in fm.fontManager.ttflist])
#       6 import matplotlib.pyplot as plt
# ----> 7 avail_font_names = [f.name for fm in matplotlib.font_manager.fontManager.ttflist]
#
# NameError: name 'matplotlib' is not defined
